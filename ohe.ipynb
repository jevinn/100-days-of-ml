# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('cars.csv')

# %%
df.sample(5)
# Out:
#         brand  km_driven    fuel         owner  selling_price
# 4047     Tata     110000  Diesel  Second Owner          70000
# 7399   Maruti     117000  Diesel   First Owner         279000
# 3995  Hyundai      40000  Petrol   First Owner         290000
# 6789   Maruti      27000  Petrol   First Owner         300000
# 897     Honda     110000  Petrol  Second Owner         165000

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
df['owner'].value_counts()
# Out:
# owner
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: count, dtype: int64

# %%
df = pd.get_dummies(df, columns=['fuel', 'owner'], drop_first=True)

# %%
df.columns
# Out:
# Index(['brand', 'km_driven', 'selling_price', 'fuel_Diesel', 'fuel_LPG',
#        'fuel_Petrol', 'owner_Fourth & Above Owner', 'owner_Second Owner',
#        'owner_Test Drive Car', 'owner_Third Owner'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
df = pd.read_csv('cars.csv')
xtrain,xtest,ytrain,ytest = train_test_split(df.iloc[:,0:4],df.iloc[:,-1],test_size=0.2,random_state=2)

# %%
xtrain.head()
# Out:
#          brand  km_driven    fuel         owner
# 5571   Hyundai      35000  Diesel   First Owner
# 2038      Jeep      60000  Diesel   First Owner
# 2957   Hyundai      25000  Petrol   First Owner
# 7618  Mahindra     130000  Diesel  Second Owner
# 6684   Hyundai     155000  Diesel   First Owner

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()

# %%
xtrain_new = ohe.fit_transform(xtrain[['fuel', 'owner']])

# %%
xtest_new = ohe.transform(xtest[['fuel','owner']])

# %%
xtrain_new.shape
# Out:
# (6502, 9)

# %%
counts = df['brand'].value_counts()

# %%
df['brand'].nunique()
threshold = 100

# %%
repl = counts[counts <= threshold].index

# %%
pd.get_dummies(df['brand'].replace(repl, 'uncommon')).sample(5)
# Out:
#         BMW  Chevrolet   Ford  Honda  Hyundai  Mahindra  Maruti  Renault  \
# 716   False      False  False   True    False     False   False    False
# 5380  False      False  False  False     True     False   False    False
# 6123  False      False  False  False    False     False   False     True
# 1218  False      False  False  False    False     False   False    False
# 957   False      False  False  False    False     False    True    False
#
#       Skoda   Tata  Toyota  Volkswagen  uncommon
# 716   False  False   False       False     False
# 5380  False  False   False       False     False
# 6123  False  False   False       False     False
# 1218  False   True   False       False     False
# 957   False  False   False       False     False
